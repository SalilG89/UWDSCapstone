# %%
import tweepy
import pandas

def mytwitfunction(mysearchstring):

 

    consumerkey =  "qZpU3S59CB5fiOXxTXM9ZvRCK"
    consumer_secret = "GmVIx3fbUzMQwmkS5fntWp2baj0nynI8sE2mEnZjED4pandATE"
    access_token = "3974835413-vAm6Mmmcfx2RoTiIwgzNc5r7FMH1vQuvkOqIvKo"
    access_secret ="LE7w5YT4tYdcYp6hPZsyUXE4J2iJNDM4IluhqXNSC5pwk"


    OAUTH_KEYS = {'consumer_key':consumerkey, 'consumer_secret':consumer_secret, 'access_token_key':access_token, 'access_token_secret':access_secret}
    auth = tweepy.OAuthHandler(OAUTH_KEYS['consumer_key'], OAUTH_KEYS['consumer_secret'])
    api = tweepy.API(auth)

    ReyTweet = tweepy.Cursor(api.search, q=mysearchstring).items(1000)

    Rey_tweetlist = []

    for tweet in ReyTweet:
   
        Rey_tweetlist.append(tweet.text)
    return Rey_tweetlist

Rey_df = pandas.DataFrame(mytwitfunction('#Sanders2020'))



Rey_df['Subject'] = 'kamala'

Rey_df.to_csv("capstone_etl_discovery_ftest22.csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\Users\Salil\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# C:\Users\Salil\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# C:\Users\Salil\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     742     addrlist = []
# --> 743     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     744         af, socktype, proto, canonname, sa = res
#
# ...
